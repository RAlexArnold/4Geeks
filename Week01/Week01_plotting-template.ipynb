# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Wine Quality Data

# %% [markdown]
# https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv

# %%
#pd.read_csv('wine_data.csv', sep=';') <-- if stored locally as wine_data.csv

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'

df = pd.read_csv(url, sep=';')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# Out:
# 20

# %% [markdown]
# For *any kind* of plot, you can change the size, add labels, change colors, add a title, change the axis scale, and more...
#
# - Change the figure size by first adding `plt.figure(figsize=(width, height)`
# - Add labels by adding the `label='text'` parameter *inside* your plotting function
# - Change colors by adding the `c='color'` parameter *inside* your plotting function
# - Change the scale by adding a new line that states `plt.xscale('log')` or `plt.yscale('log')`
# - Add axis labels by adding a new line that states `plt.xlabel('text')` or `plt.ylabel('text')`
# - You can change the transparency of the visualization by adding the `alpha=float` parameter  parameter *inside* your plotting function
#     - `alpha` must be between 0 and 1.
#     - 0 is absolutely transparent and 1 is absolutely opaque
# - Add a title by adding a new line that states `plt.title('text')`
#
# See docs for colors you can use: https://matplotlib.org/stable/gallery/color/named_colors.html
#
# `matplotlib.pyplot` will automatically cycle through the colors if there are multiple lines being plotted.
#
# - The first (auto) color is called `'C0'`, then `'C1'`, ..., up to `C9`
# - You can also specified a named color such as
#     - `'b'` for blue
#     - `'r'` for red
#     - `'k'` for black, ...

# %% [markdown]
# # Line Plots

# %% [markdown]
# See docs for the `plot` function: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html

# %%
# Just some data to play with
x = np.linspace(0, 10, 100)
y = np.exp(x)

# start with plt.plot(x,y)
# then add a label. show it does nothing. Must add plt.legend
# Then plot 10*y
# Then plot np.exp(2*x)
# Then show yscale('log')
# Then show colors
# You can show alpha too
# Show a title

plt.plot(x,y, c='blue')
plt.plot(x,10*y, c='r')
plt.plot(x, np.exp(2*x) , c='k', alpha=0.1)

plt.yscale('log')

plt.xlabel('x')
plt.ylabel('exp(x)')
plt.title('Exponential')

plt.show()

# %% [markdown]
# For a lineplot (`plot`) you can also change the **linestyle** (`ls`) and the **linewidth** (`lw`)
#
# The linestyle can be
# - `'-'` (default) Sold Line
# - `'--'` Dashed Line
# - `'-.'` Dashed-Dotted Line
# - `':'` Dotted Line

# %% [markdown]
# Another plot with `sin` and `cos`.

# %%
# plot the below. Show ls and lw parameters

x = np.linspace(0, 10, 100)

plt.plot(x, np.sin(x), label='sin(x)', lw=10)
plt.plot(x, np.cos(x), label='cos(x)', ls='--')
plt.legend()
plt.show()

# %% [markdown]
# Return to our wine dataframe

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
total_SO2 = df['total sulfur dioxide']
residual_sugar = df['residual sugar']

plt.plot(total_SO2, residual_sugar) # <--- !!
plt.show()

# %%
df['total sulfur dioxide']
# Out:
# 0       34.0
# 1       67.0
# 2       54.0
# 3       60.0
# 4       34.0
#         ...
# 1594    44.0
# 1595    51.0
# 1596    40.0
# 1597    44.0
# 1598    42.0
# Name: total sulfur dioxide, Length: 1599, dtype: float64

# %%
df['residual sugar']
# Out:
# 0       1.9
# 1       2.6
# 2       2.3
# 3       1.9
# 4       1.9
#        ...
# 1594    2.0
# 1595    2.2
# 1596    2.3
# 1597    2.0
# 1598    3.6
# Name: residual sugar, Length: 1599, dtype: float64

# %% [markdown]
# To better understand why lineplot isn't useful here, let's look at the smaller example below

# %%
x = np.random.randint(10, size=5)
x #<- notice the order of the integers here
# Out:
# array([0, 8, 6, 5, 8])

# %%
y = np.sin(x)
y
# Out:
# array([ 0.        ,  0.98935825, -0.2794155 , -0.95892427,  0.98935825])

# %%
plt.plot(x,y)

# %% [markdown]
# So a **scatter plot** will be better. We don't want to connect any points, as the **sequential order** of the data isn't meaningful to us. Only the relationship between variables

# %%
plt.scatter(x,y)

# %% [markdown]
# # Scatter Plots

# %% [markdown]
# Let's return to our dataframe

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
plt.scatter(total_SO2, residual_sugar)
plt.xlabel('Total SO2')
#plt.xlabel('Total $SO_2$') <--- Try this if you want fancy LaTeX labels. Surround your LaTex text with $
plt.ylabel('Residual Sugar')
plt.show()

# %% [markdown]
# The data is clumped together at the lower `residual sugar` and `total sulfur dioxide` values.
#
# We can change the size of the data points, and even their shape.

# %%
plt.scatter(total_SO2, residual_sugar, s=1)#, marker='+')
plt.xlabel('Total SO2')
plt.ylabel('Residual Sugar')
plt.show()

# %% [markdown]
# Changing the point size can help somewhat, but here is where using a log scale can be beneficial!

# %%
plt.scatter(total_SO2, residual_sugar, s=5)
plt.xlabel('Total SO2')
plt.ylabel('Residual Sugar')
plt.xscale('log')
plt.yscale('log')
plt.show()

# %% [markdown]
# # Histograms

# %% [markdown]
# If we want to focus on the distribution of a single feature (variable) then we can use a histogram
#
# We can set the bins using the `bins` parameter in the `plt.hist` function.
#
# - Can be an integer specifying number of bins, i.e. `bins=10` (default is 10)
# - Can be a list or array specifiying the ends points of the bins
#     - e.g. `bins=[1,2,3,4]` would be 3 bins, each bin is between the specified points
#     - use `np.arange(start, stop, step)` to generate array from `start` to `stop-step` (last point not included) with spacing of `step`
#     - use `np.linspace(start, stop, num)` to generate array from `start` to `stop` (last point included) with `num` elements
#     - use `np.logspace(start, stop, num)` to generate array like in `linspace`, but values are even spaced in a **log scale**
#         - Beginning value of log space is `base ** start` and ending value is `base ** end`
#         - So `start=2` corresonds to a starting value of 100 if the `base` keyword is `base=10`.
#
#
# We can change the visual style of the histogram using the `histtype` parameter
# - `histtype=bar` (default) Traditional style
# - `histtype=step` Unfilled bars
#
# Many other parameters. See docs: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html

# %%
np.arange(0, 100+5, 5)

np.linspace(0, 300, 50)
# Out:
# array([  0.        ,   6.12244898,  12.24489796,  18.36734694,
#         24.48979592,  30.6122449 ,  36.73469388,  42.85714286,
#         48.97959184,  55.10204082,  61.2244898 ,  67.34693878,
#         73.46938776,  79.59183673,  85.71428571,  91.83673469,
#         97.95918367, 104.08163265, 110.20408163, 116.32653061,
#        122.44897959, 128.57142857, 134.69387755, 140.81632653,
#        146.93877551, 153.06122449, 159.18367347, 165.30612245,
#        171.42857143, 177.55102041, 183.67346939, 189.79591837,
#        195.91836735, 202.04081633, 208.16326531, 214.28571429,
#        220.40816327, 226.53061224, 232.65306122, 238.7755102 ,
#        244.89795918, 251.02040816, 257.14285714, 263.26530612,
#        269.3877551 , 275.51020408, 281.63265306, 287.75510204,
#        293.87755102, 300.        ])

# %%
plt.hist(total_SO2)
plt.xlabel('Total SO2')
plt.ylabel('Counts')
plt.show()

# %%
#np.arange(0, 300, 1)

np.logspace(0, 2, 10)
# Out:
# array([  1.        ,   1.66810054,   2.7825594 ,   4.64158883,
#          7.74263683,  12.91549665,  21.5443469 ,  35.93813664,
#         59.94842503, 100.        ])

# %%
plt.hist(total_SO2, fill=False, bins=np.logspace(-1, 3, 50)) # can also use np.log10(total_SO2.max()) to find the maximum value in logspace
plt.xlabel('Total SO')
plt.ylabel('Counts')
plt.xscale('log')
plt.show()

# %% [markdown]
# # Box Plots

# %% [markdown]
# ![562631285786577fa3e522788521cd4029fa97fe858480358a86e49ed9ae7cc3.png](attachment:562631285786577fa3e522788521cd4029fa97fe858480358a86e49ed9ae7cc3.png)

# %%
plt.boxplot(total_SO2, vert=False, labels=['Total SO2'])
plt.show()

# %%
print(f'Median Value {total_SO2.median()}')
print(f'Mean Value {total_SO2.mean()}')

for q_value in [0.25, 0.5, 0.75]:
    print(int(q_value/.25), np.quantile(total_SO2, q=q_value))
# Out:
# Median Value 38.0
# Mean Value 46.46779237023139
# 1 22.0
# 2 38.0
# 3 62.0

# %%
plt.boxplot(df, labels=df.columns, vert=True)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Can we rotate the xaxis labels?
#
# Google "plt rotate x labels" and check *Stack Overflow*
#
# https://stackoverflow.com/questions/10998621/rotate-axis-tick-labels

# %% [markdown]
# # Bar Plots and Pie Charts for Categorical Data

# %% [markdown]
# When we have **categorical data**, that is data that can easily be divided or represented by groups, then a **bar plot** or **pie chart** is best.

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# Let's use the `quality` feature to make categorical data. Use the `quality` as a category.
#
# Let's count how many data points there are for each quality-category

# %%
quality_counts = df['quality'].value_counts()
quality_counts
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %% [markdown]
# Let's make a bar plot of the counts for each quality group.

# %% [markdown]
# If we tried this with a **histogram**, check what happens

# %%
plt.hist(quality_counts)
# Out:
# (array([3., 0., 1., 0., 0., 0., 0., 0., 0., 2.]),
#  array([ 10. ,  77.1, 144.2, 211.3, 278.4, 345.5, 412.6, 479.7, 546.8,
#         613.9, 681. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Doesn't give us what we want. So we must use a **bar plot** using `plt.bar(x, height)`

# %%
plt.bar(quality_counts) #<--- this alone won't work. Need an 'x' and 'y' separately
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 plt.bar(quality_counts)
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
print(quality_counts.index) #<--- these will be our category labels
print()
print(quality_counts.values) #<--- these will be the counts that are plotted for each category. 
# Series.values turns a series into a numpy array
# Out:
# Int64Index([5, 6, 7, 4, 8, 3], dtype='int64')
#
# [681 638 199  53  18  10]

# %%
plt.bar(quality_counts.index, quality_counts)
plt.xlabel('Quality Value')
plt.ylabel('Number of Wines')
# Out:
# Text(0, 0.5, 'Number of Wines')

# %% [markdown]
# Bar plots don't just have to plot counts, we could use `groupby` to find various values of each quality-category
#
# Below, we find the mean pH of each quality group

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
quality_pH = df.groupby(['quality'])['pH'].mean()
quality_pH
# Out:
# quality
# 3    3.398000
# 4    3.381509
# 5    3.304949
# 6    3.318072
# 7    3.290754
# 8    3.267222
# Name: pH, dtype: float64

# %%
plt.bar(quality_pH.index, quality_pH)
plt.xlabel('Quality Value')
plt.ylabel('pH')
# Out:
# Text(0, 0.5, 'pH')

# %% [markdown]
# It's hard to tell the bars apart, so we can change the y-axis limits using `plt.ylim(min, max)` (`plt.xlim` also exists)
#
# Note that `plt.ylim` works for *any kind* of plot, not just bar plots

# %%
plt.bar(quality_pH.index, quality_pH)
plt.xlabel('Quality Value')
plt.ylabel('pH')
plt.ylim(3.0,3.5)
# Out:
# (3.0, 3.5)

# %% [markdown]
# Let's go back to our counts for each quality and plot these on a **pie chart**

# %%
quality_counts = df['quality'].value_counts()
quality_counts
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
plt.pie(quality_counts, labels=quality_counts.index)
plt.title('Pie Chart of Quality Counts')
plt.show()

# %% [markdown]
# # Using Pandas to Quickly Plot

# %% [markdown]
# You can also make plots directly from pandas dataframes and series (it makes use of matplotlib)
#
# But they can be more difficult to customize

# %% [markdown]
# See docs:
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.hist.html

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# **Line Plots**

# %%
df.plot() # <--- by default will make plot of index vs each feature. Not so useful in our case
# Out:
# <Axes: >

# %% [markdown]
# **Histograms**

# %%
df['fixed acidity'].hist() #<--- quickly makes histogram of fixed acidity
#df['fixed acidity'].plot(kind='hist') #<--- this also will work
# Out:
# <Axes: >

# %% [markdown]
# **Scatter Plots**

# %% [markdown]
# Use the `kind` argument in the `plot` function to specify what type of plot you want.
#
# Must specify an `x` and `y` parameter

# %%
df.plot(x='fixed acidity', y='citric acid', kind='scatter')
# Out:
# <Axes: xlabel='fixed acidity', ylabel='citric acid'>

# %% [markdown]
# **Bar Plots**

# %%
df#.groupby(['quality']).mean()['pH']#.plot(kind='bar')

# %% [markdown]
# Check the docs for more options!

# %% [markdown]
# # Subplots

# %% [markdown]
# Notice that each of the above plot returned an `<Axes: >` object.
#
# In all our previous examples, matplotlib was making what are called axes objects.
#
# An axes object is like a blank canvas that can hold and draw your plots. It is a space where you can place your data opints, lines, bars, etc.
#
# We can have more flexibility and customizing with how we plot if we start working with these axes objects directly!
#
# But it can get a big more challenging. So once you are comfortable with the above approaches to plotting, you can start modifying axes objects.

# %% [markdown]
# This is where **subplots** come into play.
#
# `f, axs = plt.subplots(n_rows, n_cols)`

# %%
f, axs = plt.subplots(6, 4, figsize=(5,10))

# %%
axs[1,3].hist(df['total sulfur dioxide'])
f

# %%
axs[0].hist(df['total sulfur dioxide']) #<---- but where is the plot?
# Out:
# (array([730., 471., 221., 113.,  52.,  10.,   0.,   0.,   0.,   2.]),
#  array([  6. ,  34.3,  62.6,  90.9, 119.2, 147.5, 175.8, 204.1, 232.4,
#         260.7, 289. ]),
#  <BarContainer object of 10 artists>)

# %%
f      #<--- there it is 

# f is the variable that stores the final figure image.

# It'll be eaiser it we keep our plotting all in one cell.

# %% [markdown]
# Let's keep our (sub-)plotting in one cell to avoid having to retype `f`, the figure variable

# %% [markdown]
# Some of our commands for modifying our plots haved changed now for subplots
#
# e.g.
#
# - use `.set_xlabel` instead of `xlabel` to change each axes-object's axis-label titles
# - use `.set_title` instead of `title` to change each axes-object's title
# - use `.set_xlim` instead of `xlim` to change each axes-oject's axis-limits
#
# - ... typically, for `subplots` you use `.set_` before the name of the function to change something
#
# - use `.suptitle` to set an overall title for the entire figure
#
# - You can set the parameters `sharex` and `sharey` to a boolean values in the `subplots` function to share axis values between axes-objects
#
# - And use `plt.tight_layout()` to adjust spacing betwen subplots

# %%
f, axs = plt.subplots(2, 1) #, sharex=True)

axs[0].hist(df['total sulfur dioxide'])
axs[1].hist(df['free sulfur dioxide'])

axs[0].set_xlabel('Total Sulur Dioxide') #<--- notice that we use set_xlabel
axs[1].set_xlabel('Free Sulfur Dioxide') 

axs[0].set_title('Total SO2 Distribution') #<--- notice that we use set_title
axs[1].set_title('Free SO2 Distribution')

axs[0].set_xlim(0, 200)

axs[1].set_yscale('log')

plt.suptitle('SO2 Distributions')

plt.tight_layout()

plt.show()

# %% [markdown]
# Start practicing with subplots so you can get the hang for them.
#
# If you just want to quickly plot something, you can use the "regular" non-subplot methods to make them quickly.
#
# But if you want to start making more "serious" plots that you can have more control over, use `subplots`

# %% [markdown]
# # Seaborn

# %% [markdown]
# **Seaborn** is another plotting package that builds off of matplotlib. So you should feel comfortable with matplotlib before moving to seaborn. But once you do, you'll see it's very powerful and is built for use with **pandas dataframes**
#
# Import seaborn using
#
# `import seaborn as sns`

# %%
import seaborn as sns

# %% [markdown]
# Let's plot some data from our wine dataframe, `df`

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# **Scatter Plots**

# %%
sns.scatterplot(data=df, x='fixed acidity', y='volatile acidity')
# Out:
# <Axes: xlabel='fixed acidity', ylabel='volatile acidity'>

# %% [markdown]
# The power of seaborn is that it is very easy to use *dataframe features* to change aspects of the plot
#
# For example, the `hue` keyword can change the color of the data based off the feature (column) given

# %%
sns.scatterplot(data=df, x='fixed acidity', y='volatile acidity', hue='pH')
# Out:
# <Axes: xlabel='fixed acidity', ylabel='volatile acidity'>

# %% [markdown]
# You can change the color palette using the `palette` parameter
#
# See docs: https://seaborn.pydata.org/generated/seaborn.scatterplot.html
#
# See `color_palette` docs to get an idea of some of the different palettes to use: https://seaborn.pydata.org/generated/seaborn.color_palette.html#seaborn.color_palette

# %%
sns.scatterplot(data=df, x='fixed acidity', y='volatile acidity', hue='pH', palette='flare')
# Out:
# <Axes: xlabel='fixed acidity', ylabel='volatile acidity'>

# %% [markdown]
# Changing the hue also works for categorical data

# %% [markdown]
# We can see it for the wine `quality`...

# %%
sns.scatterplot(data=df, x='fixed acidity', y='volatile acidity', hue='quality')
# Out:
# <Axes: xlabel='fixed acidity', ylabel='volatile acidity'>

# %% [markdown]
# ... and the categorical data doesn't even have to be a number for seaborn to use it in the `hue` parameter
#
# Take a look at the iris flower dataset below.

# %%
iris = sns.load_dataset('iris') #<--- load_dataset function has easily accessible toy datasets you can load up
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500/>
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We can color-code the data by the iris `species` name, even though it is a string

# %%
sns.scatterplot(data=iris, x='sepal_length', y='sepal_width', hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# We can also change the size of the datapoints
#
# - `s=num` will set the size of all points to the given float or integer value
# - `size='column_label'` will set the size of each data point based off that data's `column_label` value

# %%
sns.scatterplot(data=iris, x='sepal_length', y='sepal_width', hue='species', s=100)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.scatterplot(data=iris, x='sepal_length', y='sepal_width', hue='species', size='petal_length')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# **Histograms**

# %%
sns.histplot(data=iris, x='sepal_length')

# %%
sns.histplot(data=iris, x='sepal_length', hue='species')

# %%
sns.histplot(data=iris, x='sepal_length', hue='species', multiple='stack')

# %%
sns.histplot(data=iris, x='sepal_length', hue='species', element='step')

# %% [markdown]
# **Box Plots and Strip Plots**

# %%
iris.columns

# %%
sns.boxplot(data=iris)

# %%
sns.boxplot(data=iris, x='species', y='sepal_length')

# %%
sns.stripplot(data=iris, x='species', y='sepal_length')

# %% [markdown]
# **Pair Plot**

# %% [markdown]
# A powerful plot one can use in seaborn is a **pair plot**
#
# This makes a square grid of plots which shows a scatterplot of each feature against itself, as well as a histogram of each feature.
#
# But **be careful** because it can be **very slow** for data sets with many columns (>6) as it makes $N^2$ plots, where $N$ is the number of columns

# %%
sns.pairplot(data=iris)#, hue='species')

# %% [markdown]
# **Correlation Matrix and Heat Maps**

# %% [markdown]
# An alternative to using the pair plot, that will still work well with larger dataframes, is to calculate the correlation between each column.
#
# The **pearson correlation coefficient**, $r$, measures the linear relationship between two sets of data. It lies between -1 and +1.
#
# - $r=+1$ means thre is a perfect positive linear relationship between the two given sets of data
#
# - $r=0$ means there is no linear relationship
#
# - $r=-1$ means there is a perfect negative linear relationshp

# %% [markdown]
# More info on the **Pearson correlation coefficient**: https://www.scribbr.com/statistics/pearson-correlation-coefficient/

# %%
corr_df = iris.corr(numeric_only=True)
corr_df
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %% [markdown]
# And correlations can be visualized with a **heatmap**

# %%
sns.heatmap(corr_df, annot=True) #, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# **Using subplots with Seaborn**

# %% [markdown]
# You can also use subplots with seaborn plots.
#
# Define the figure, `f` and axes object(s) `axs` using `plt.subplots()`
#
# And then submit the axes object as a parameter to the seaborn plotting function of your choice

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
# Plot sepal length vs speal width in top left
# Plot sepal length vs petal width in bottom left
# Plot boxplot of sepal width for each spcies in top right
# Plot boxplot of petal weidth for each species in bottom right

f, axs = plt.subplots(2,2, figsize=(8,8))

print(axs)

#sns.scatterplot(data=iris, x='sepal_length', y='sepal_width', ax=axs[0,0], hue='species')
#sns.scatterplot(data=iris, x='sepal_length', y='petal_width', ax=axs[1,0], hue='species')
#sns.boxplot(data=iris, x='species', y='sepal_width', ax= axs[0,1])
#sns.boxplot(data=iris, x='species', y='petal_width', ax= axs[1,1])

#axs[0,0].set_xlabel('Sepal Length')
#axs[0,0].set_ylabel('Sepal Width')

#axs[1,0].set_xlabel('Sepal Length')
#axs[1,0].set_ylabel('Petal Width')

#axs[0,1].set_xlabel('Species')
#axs[0,1].set_ylabel('Sepal Width')

#axs[1,1].set_xlabel('Species')
#axs[1,1].set_ylabel('Petal Width')

#plt.suptitle('Iris Data')

#plt.tight_layout()

# %% [markdown]
# # Play Around With DataSets

# %% [markdown]
# Seaborn has a lot of data that you can easily access (with internet connection) and play around with
#
# Use the `sns.load_dataset` function and provide the name of the data set
#
# Docs for `load_dataset`: https://seaborn.pydata.org/generated/seaborn.load_dataset.html
#
# List of datasets can be found here: https://github.com/mwaskom/seaborn-data
#
# E.g.
#
# `pd.load_dataset('planets')`
#
# Note: Don't include the `.csv` in the name

# %% [markdown]
# You can also directly access some datasets by entering the URL into `pd.load_csv('url_link')`
#
# - Iris dataset: https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv
#
# - Wine dataset: https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv
