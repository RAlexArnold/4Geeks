# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Loading DataFrames and Grabbing Values

# %% [markdown]
# Let's load a dataset from a csv file.
#
# In Machine Learning a "dataset" is the data we use for our experiment.
#
# Let's use the `read_csv` function from **pandas** to load a dataset from a comma seperated value (csv) file.
#
# The Docs for `read_csv`. When in doubt about what a function does, read the docs!
#
# https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
#
# We see that `read_csv` takes a string input which represents the location, or path of a file.
#
# The path can be on your local computer, or a URL
#
# We also see that `read_csv` returns a **DataFrame**

# %%
file_path = 'pokemon_data.csv'

df = pd.read_csv(file_path)
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# The csv file is stored as a **DataFrame**
#
# We can also make **DataFrames** from data.
#
# For example, suppose we have a python `list` of `lists` (analagous to a two-dimensional array)

# %%
car_data = [["Toyota", "Corolla", "Blue", 5, 2.45], 
            ["Toyota", "Prius", "Grey", 3, 3.45],
            ["Toyota", "4Runner", "Blue", 6, 6.53],
            ["Ford", "K", "Yellow", 10, 23.23], 
            ["Ford", "T", "Black", 12, 53.5],
            ["Porsche", "Cayenne", "White", 150, 230.32],
            ["Porsche", "Panamera", "Red", 200, 333.3],
            ["Porsche", "Panamera", "White", 190, 89.3]]

# %%
pd.DataFrame(car_data)
# Out:
#          0         1       2    3       4
# 0   Toyota   Corolla    Blue    5    2.45
# 1   Toyota     Prius    Grey    3    3.45
# 2   Toyota   4Runner    Blue    6    6.53
# 3     Ford         K  Yellow   10   23.23
# 4     Ford         T   Black   12   53.50
# 5  Porsche   Cayenne   White  150  230.32
# 6  Porsche  Panamera     Red  200  333.30
# 7  Porsche  Panamera   White  190   89.30

# %%
car_df = pd.DataFrame(car_data, columns=['Brand', 'Model', 'Color', 'Value1', 'Value2'])
car_df
# Out:
#      Brand     Model   Color  Value1  Value2
# 0   Toyota   Corolla    Blue       5    2.45
# 1   Toyota     Prius    Grey       3    3.45
# 2   Toyota   4Runner    Blue       6    6.53
# 3     Ford         K  Yellow      10   23.23
# 4     Ford         T   Black      12   53.50
# 5  Porsche   Cayenne   White     150  230.32
# 6  Porsche  Panamera     Red     200  333.30
# 7  Porsche  Panamera   White     190   89.30

# %% [markdown]
# We can also create a DataFrame using a list of python `dictionaries` which specify the DataFrame column as a dictionary key, and the DataFrame value as the dictionary value.

# %%
car_dict = [
    { 
        "brand": "Toyota", 
        "make": "Corolla",
        "color": "Blue"
    },
    {
        "brand": "Ford", 
        "make": "K",
        "color": "Yellow"
    },
    {
        "brand": "Porche", 
        "make": "Cayenne",
        "color": "White"
    }
]

# %%
pd.DataFrame(car_dict)
# Out:
#     brand     make   color
# 0  Toyota  Corolla    Blue
# 1    Ford        K  Yellow
# 2  Porche  Cayenne   White

# %% [markdown]
# **DataFrames** are one of two main ways data is stored in **pandas**, the other being a **Series**
#
# These ways of storing, or structuring data are called **Data structures**. So **DataFrames** and **Series** are types of **Data Structures**.

# %% [markdown]
# DataFrames are like spreadsheets. They are two-dimensional data structures.
#
# They are like 2D arrays in **Numpy**, but with some differences.
#
# 1.) DataFrames have row and column indices
#
#    - **Row Index** An array of labels associated to the rows
#
#    - **Column Index** An array of labels associated to the columns
#
# 2.) Each column in a DataFrame can store a different **Data Type** (how data is stored, e.g. **float**, **integer**, **string**, **object**, etc.), while for Numpy all values in the array will have the same data type.

# %% [markdown]
# Let's focus on point 1.)
#
# Imagine a dataframe presented below.
#
# - The **Data** is the array of numerica values, (*[3, 0], [2, 3], ....* )
#
# - The **Row Index** is the label of each row (*0, 1, 2, 3*). These are commonly integers but they don't have to be!
#
# - The **Column Index** is the label of each columns (*apples, oranges*)

# %% [markdown]
# ![dataframe.PNG](attachment:dataframe.PNG)

# %% [markdown]
# **Accessing Values, Rows, Columns**

# %%
car_df
# Out:
#      Brand     Model   Color  Value1  Value2
# 0   Toyota   Corolla    Blue       5    2.45
# 1   Toyota     Prius    Grey       3    3.45
# 2   Toyota   4Runner    Blue       6    6.53
# 3     Ford         K  Yellow      10   23.23
# 4     Ford         T   Black      12   53.50
# 5  Porsche   Cayenne   White     150  230.32
# 6  Porsche  Panamera     Red     200  333.30
# 7  Porsche  Panamera   White     190   89.30

# %% [markdown]
# With Pandas DataFrames, we can access data by a rows and column labels using `.loc`
#
# `.loc` requires the actual row/column labels to be used

# %%
car_df.loc[3, 'Model'] # <- So this works
# Out:
# 'K'

# %%
car_df.loc[3, 1] # <- But what about this!??
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# `loc` requires the original/actual index labels. There is no column label called "1" so the above fails

# %% [markdown]
# Let's continue with `loc`

# %%
# We can select a single row...
car_df.loc[2] #< - Notice the output of this looks a little different. 
# It's a Series, not a DataFrame. We'll come back to this in a moment
# Out:
# Brand      Toyota
# Model     4Runner
# Color        Blue
# Value1          6
# Value2       6.53
# Name: 2, dtype: object

# %%
# ... or multiple rows (place the row indices between square brackets)
car_df.loc[[2, 5]]
# Out:
#      Brand    Model  Color  Value1  Value2
# 2   Toyota  4Runner   Blue       6    6.53
# 5  Porsche  Cayenne  White     150  230.32

# %% [markdown]
# When using doulbe brackets with `loc`, the *first set* of inner-most brackets signify the row-indices we use. So in the above, we will use rows 2 and 5.

# %% [markdown]
# Any *second set* of innter-most brackets will signify the column labels we use.
#
# So in the below we will use rows 3 and 5 (the first set of inner most brackets),
#
# and we will use columns `Model` and `Color` (the second set of inner most brackets).

# %%
# We can select multiple rows and multiple columns
car_df.loc[[3,5], ['Model', 'Color']]
# Out:
#      Model   Color
# 3        K  Yellow
# 5  Cayenne   White

# %% [markdown]
# Notice that using double brackets will return a **DataFrame**, while a single bracket will return a **Series**, even if we use a single row.
#
# We'll explore what a **Series** in a bit.

# %% [markdown]
# But for now to get a taste of **DataFrames** vs **Series**, compare...

# %%
car_df.loc[3]
# Out:
# Brand       Ford
# Model          K
# Color     Yellow
# Value1        10
# Value2     23.23
# Name: 3, dtype: object

# %% [markdown]
# ... to

# %%
car_df.loc[[3]]
# Out:
#   Brand Model   Color  Value1  Value2
# 3  Ford     K  Yellow      10   23.23

# %% [markdown]
# Again, notice how using double brackets changes the output.

# %%
# A series...
car_df.loc[3, 'Model']
# Out:
# 'K'

# %%
# vs. a DataFrame
car_df.loc[[3],['Model']]
# Out:
#   Model
# 3     K

# %% [markdown]
# We can also access data by rows and columns using `.iloc`.
#
# But `.iloc` requires the *integer position* of each row and each column.
#
# It doesn't want the original index label. It wants an integer.

# %%
# So check what happens here. 
car_df.iloc[3, 'Model'] # <- ! 'Model' is not an integer position
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:873, in _LocationIndexer._validate_tuple_indexer(self, key)
#     872 try:
# --> 873     self._validate_key(k, i)
#     874 except ValueError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1483, in _iLocIndexer._validate_key(self, key, axis)
#    1482 else:
# -> 1483     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[155], line 2
#       1 # So check what happens here.
# ...

# %%
car_df.iloc[3, 1] # So if we are using .iloc we need the integer position of the row label and the column label
# Out:
# 'K'

# %%
# We can also grab multiple rows and columns with .loc
car_df.loc[[5,6,7], ['Model', 'Color', 'Value1']]
# Out:
#       Model  Color  Value1
# 5   Cayenne  White     150
# 6  Panamera    Red     200
# 7  Panamera  White     190

# %%
# Or we could use .iloc.
car_df.iloc[[5,6,7], [2,3,4]]
# Out:
#    Color  Value1  Value2
# 5  White     150  230.32
# 6    Red     200  333.30
# 7  White     190   89.30

# %%
# Showing the car_df again 
car_df
# Out:
#      Brand     Model   Color  Value1  Value2
# 0   Toyota   Corolla    Blue       5    2.45
# 1   Toyota     Prius    Grey       3    3.45
# 2   Toyota   4Runner    Blue       6    6.53
# 3     Ford         K  Yellow      10   23.23
# 4     Ford         T   Black      12   53.50
# 5  Porsche   Cayenne   White     150  230.32
# 6  Porsche  Panamera     Red     200  333.30
# 7  Porsche  Panamera   White     190   89.30

# %%
# There are also a few ways to grab all values of a column or columns
# The ":" in the row index position means to use all rows

car_df.loc[:, 'Color'] #<- Notice the output looks different
# Out:
# 0      Blue
# 1      Grey
# 2      Blue
# 3    Yellow
# 4     Black
# 5     White
# 6       Red
# 7     White
# Name: Color, dtype: object

# %%
# Or just
car_df['Color']
# Out:
# 0      Blue
# 1      Grey
# 2      Blue
# 3    Yellow
# 4     Black
# 5     White
# 6       Red
# 7     White
# Name: Color, dtype: object

# %% [markdown]
# Notice that accessing values form DataFrames differs from how we access values from Numpy arrays
#
# Numpy arrays have no index, so we just use the integer position (row, column) of the value of interest

# %%
car_array = np.array(car_df)
car_array
# Out:
# array([['Toyota', 'Corolla', 'Blue', 5, 2.45],
#        ['Toyota', 'Prius', 'Grey', 3, 3.45],
#        ['Toyota', '4Runner', 'Blue', 6, 6.53],
#        ['Ford', 'K', 'Yellow', 10, 23.23],
#        ['Ford', 'T', 'Black', 12, 53.5],
#        ['Porsche', 'Cayenne', 'White', 150, 230.32],
#        ['Porsche', 'Panamera', 'Red', 200, 333.3],
#        ['Porsche', 'Panamera', 'White', 190, 89.3]], dtype=object)

# %%
# Accessing a value in an array
car_array[1,2]
# Out:
# 'Grey'

# %% [markdown]
# Let's return to our `car_df` dataframe

# %%
# Let's grab the Color column again
car_df['Color']
# Out:
# 0      Blue
# 1      Grey
# 2      Blue
# 3    Yellow
# 4     Black
# 5     White
# 6       Red
# 7     White
# Name: Color, dtype: object

# %% [markdown]
# You may have noticed the output of the above looks slightly different than our DataFrame outputs. It doesn't appear to have a **column index**, only **row indices**
#
# That's because the above is a **Series**, not a dataframe.
#
# A **Series** is a one-dimensional labeled data structure. It has a **row index**, but lacks a **column index**

# %%
car_df # Show the dataframe for car_df
# Out:
#      Brand     Model   Color  Value1  Value2
# 0   Toyota   Corolla    Blue       5    2.45
# 1   Toyota     Prius    Grey       3    3.45
# 2   Toyota   4Runner    Blue       6    6.53
# 3     Ford         K  Yellow      10   23.23
# 4     Ford         T   Black      12   53.50
# 5  Porsche   Cayenne   White     150  230.32
# 6  Porsche  Panamera     Red     200  333.30
# 7  Porsche  Panamera   White     190   89.30

# %%
color_series = car_df['Color'] #Selecting a column with single brackets returns a series of that column
color_series
# Out:
# 0      Blue
# 1      Grey
# 2      Blue
# 3    Yellow
# 4     Black
# 5     White
# 6       Red
# 7     White
# Name: Color, dtype: object

# %% [markdown]
# We can still access values using `loc` or `.iloc`

# %%
color_series.loc[3]
# Out:
# 'Yellow'

# %% [markdown]
# But note, that if we use only a bracket (no `loc` or `iloc`) on a series, it assumes a row index is given in the bracket

# %%
color_series[3]
# Out:
# 'Yellow'

# %% [markdown]
# If we wanted to keep the `Color` information from `car_df` as a **dataframe**, and not a **series** then we need to use double brackets

# %%
car_df[['Color']]
# Out:
#     Color
# 0    Blue
# 1    Grey
# 2    Blue
# 3  Yellow
# 4   Black
# 5   White
# 6     Red
# 7   White

# %% [markdown]
# Practice, practice, practice to get a hang of series vs dataframes, and iloc vs loc

# %% [markdown]
# # Filtering
#
# We can also filter dataframes using a combinations of **logical conditions** and `.loc` or `.iloc`
#
# Let's return to our Pokemon dataframe, `df`.

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# Suppose we want to grab only the Pokemon (rows) whose primary types are Grass

# %%
df['Type 1']
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3        Grass
# 4         Fire
#         ...
# 795       Rock
# 796       Rock
# 797    Psychic
# 798    Psychic
# 799       Fire
# Name: Type 1, Length: 800, dtype: object

# %%
# Write the logical condition. 
# This returns a series boolean values
df['Type 1'] == 'Grass'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Type 1, Length: 800, dtype: bool

# %% [markdown]
# If we have a **series** of **booleans** (`True` or `False`) then we can filter the rows of our dataframe with this boolean series.
#
# But for this to work, our boolean series must be the same length as the number of rows in our dataframe
#
# Here, we made the boolean series using our Pokemon dataframe, so the lengths will match.
#
# This boolean series used for filtering is called a **mask**

# %% [markdown]
# We can filter our dataframe using the **mask** in two ways.
#
# Note, that this will keep rows where the **mask** is `True`, and remove rows where the **mask** is `False`

# %%
mask = df['Type 1'] == 'Grass'

# Method 1 with loc
df.loc[mask]
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# Method 2
df[mask]
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# We could have also just written the above as
df[df['Type 1'] == 'Grass']
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# Another example with a smaller dataframe...

# %%
car_df
# Out:
#      Brand     Model   Color  Value1  Value2
# 0   Toyota   Corolla    Blue       5    2.45
# 1   Toyota     Prius    Grey       3    3.45
# 2   Toyota   4Runner    Blue       6    6.53
# 3     Ford         K  Yellow      10   23.23
# 4     Ford         T   Black      12   53.50
# 5  Porsche   Cayenne   White     150  230.32
# 6  Porsche  Panamera     Red     200  333.30
# 7  Porsche  Panamera   White     190   89.30

# %%
# Suppose we want to filter cars with a Value1 parameter greater than 10...
car_df['Value1'] > 10
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6     True
# 7     True
# Name: Value1, dtype: bool

# %%
car_df[ car_df['Value1'] > 10 ]
# Out:
#      Brand     Model  Color  Value1  Value2
# 4     Ford         T  Black      12   53.50
# 5  Porsche   Cayenne  White     150  230.32
# 6  Porsche  Panamera    Red     200  333.30
# 7  Porsche  Panamera  White     190   89.30

# %% [markdown]
# # Adding New Columns

# %% [markdown]
# We can also create new columns based off existing data, and add them to the dataframe.
#
# Let's do this with `car_df`

# %%
car_df
# Out:
#      Brand     Model   Color  Value1  Value2
# 0   Toyota   Corolla    Blue       5    2.45
# 1   Toyota     Prius    Grey       3    3.45
# 2   Toyota   4Runner    Blue       6    6.53
# 3     Ford         K  Yellow      10   23.23
# 4     Ford         T   Black      12   53.50
# 5  Porsche   Cayenne   White     150  230.32
# 6  Porsche  Panamera     Red     200  333.30
# 7  Porsche  Panamera   White     190   89.30

# %% [markdown]
# Suppose we wanted to `add` columns `Value1` and `Value2` and save this as a new column

# %%
car_df['Value1'] + car_df['Value2'] #<- alone, this isn't yet stored in the car_df dataframe
# Out:
# 0      7.45
# 1      6.45
# 2     12.53
# 3     33.23
# 4     65.50
# 5    380.32
# 6    533.30
# 7    279.30
# dtype: float64

# %%
car_df['Value Sum'] = car_df['Value1'] + car_df['Value2']

car_df
# Out:
#      Brand     Model   Color  Value1  Value2  Value Sum
# 0   Toyota   Corolla    Blue       5    2.45       7.45
# 1   Toyota     Prius    Grey       3    3.45       6.45
# 2   Toyota   4Runner    Blue       6    6.53      12.53
# 3     Ford         K  Yellow      10   23.23      33.23
# 4     Ford         T   Black      12   53.50      65.50
# 5  Porsche   Cayenne   White     150  230.32     380.32
# 6  Porsche  Panamera     Red     200  333.30     533.30
# 7  Porsche  Panamera   White     190   89.30     279.30

# %%
# We could hav also used predefined functions listed in the Pre-Work
car_df['Value1'].add(car_df['Value2'])
# Out:
# 0      7.45
# 1      6.45
# 2     12.53
# 3     33.23
# 4     65.50
# 5    380.32
# 6    533.30
# 7    279.30
# dtype: float64

# %%
# Adding also works for strings. It will combine the strings together
car_name = car_df['Brand'] + car_df['Model']
car_name
# Out:
# 0      ToyotaCorolla
# 1        ToyotaPrius
# 2      Toyota4Runner
# 3              FordK
# 4              FordT
# 5     PorscheCayenne
# 6    PorschePanamera
# 7    PorschePanamera
# dtype: object

# %%
car_name = car_df['Brand'] + ' ' + car_df['Model']
car_df['Car Name'] = car_name

car_df
# Out:
#      Brand     Model   Color  Value1  Value2  Value Sum          Car Name
# 0   Toyota   Corolla    Blue       5    2.45       7.45    Toyota Corolla
# 1   Toyota     Prius    Grey       3    3.45       6.45      Toyota Prius
# 2   Toyota   4Runner    Blue       6    6.53      12.53    Toyota 4Runner
# 3     Ford         K  Yellow      10   23.23      33.23            Ford K
# 4     Ford         T   Black      12   53.50      65.50            Ford T
# 5  Porsche   Cayenne   White     150  230.32     380.32   Porsche Cayenne
# 6  Porsche  Panamera     Red     200  333.30     533.30  Porsche Panamera
# 7  Porsche  Panamera   White     190   89.30     279.30  Porsche Panamera

# %%
# But the below won't work directly
# Why?

car_df['Brand'] + car_df['Value1']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:165, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 try:
# --> 165     result = func(left, right)
#     166 except TypeError:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:241, in evaluate(op, a, b, use_numexpr)
#     239     if use_numexpr:
#     240         # error: "None" not callable
# --> 241         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:129, in _evaluate_numexpr(op, op_str, a, b)
#     128 if result is None:
# --> 129     result = _evaluate_standard(op, op_str, a, b)
#     131 return result
#
# ...

# %%
# But we can get around the above error if we re-cast the Value1 column as a string
car_type = car_df['Brand'] + car_df['Value1'].astype(str)
car_type
# Out:
# 0       Toyota5
# 1       Toyota3
# 2       Toyota6
# 3        Ford10
# 4        Ford12
# 5    Porsche150
# 6    Porsche200
# 7    Porsche190
# dtype: object

# %%
car_df['Car Type'] = car_type

car_df
# Out:
#      Brand     Model   Color  Value1  Value2  Value Sum          Car Name  \
# 0   Toyota   Corolla    Blue       5    2.45       7.45    Toyota Corolla
# 1   Toyota     Prius    Grey       3    3.45       6.45      Toyota Prius
# 2   Toyota   4Runner    Blue       6    6.53      12.53    Toyota 4Runner
# 3     Ford         K  Yellow      10   23.23      33.23            Ford K
# 4     Ford         T   Black      12   53.50      65.50            Ford T
# 5  Porsche   Cayenne   White     150  230.32     380.32   Porsche Cayenne
# 6  Porsche  Panamera     Red     200  333.30     533.30  Porsche Panamera
# 7  Porsche  Panamera   White     190   89.30     279.30  Porsche Panamera
#
#      Car Type
# 0     Toyota5
# 1     Toyota3
# 2     Toyota6
# 3      Ford10
# 4      Ford12
# 5  Porsche150
# 6  Porsche200
# 7  Porsche190

# %% [markdown]
# # Value Counts, Sort Values

# %% [markdown]
# Many times we will want to inspect or manipulate data *within* a column

# %% [markdown]
# `value_counts()` can tell us how many times a particular value appears in a column
#
# Read the docs
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.value_counts.html

# %%
car_df
# Out:
#      Brand     Model   Color  Value1  Value2  Value Sum          Car Name  \
# 0   Toyota   Corolla    Blue       5    2.45       7.45    Toyota Corolla
# 1   Toyota     Prius    Grey       3    3.45       6.45      Toyota Prius
# 2   Toyota   4Runner    Blue       6    6.53      12.53    Toyota 4Runner
# 3     Ford         K  Yellow      10   23.23      33.23            Ford K
# 4     Ford         T   Black      12   53.50      65.50            Ford T
# 5  Porsche   Cayenne   White     150  230.32     380.32   Porsche Cayenne
# 6  Porsche  Panamera     Red     200  333.30     533.30  Porsche Panamera
# 7  Porsche  Panamera   White     190   89.30     279.30  Porsche Panamera
#
#      Car Type
# 0     Toyota5
# 1     Toyota3
# 2     Toyota6
# 3      Ford10
# 4      Ford12
# 5  Porsche150
# 6  Porsche200
# 7  Porsche190

# %%
car_df['Brand'].value_counts()
# Out:
# Toyota     3
# Porsche    3
# Ford       2
# Name: Brand, dtype: int64

# %% [markdown]
# The `ascending` keyword changes the order of the resulting **Series**

# %%
car_df['Brand'].value_counts(ascending=True)
# Out:
# Ford       2
# Toyota     3
# Porsche    3
# Name: Brand, dtype: int64

# %% [markdown]
# Another example

# %%
car_df['Color'].value_counts()
# Out:
# Blue      2
# White     2
# Grey      1
# Yellow    1
# Black     1
# Red       1
# Name: Color, dtype: int64

# %% [markdown]
# `value_counts()` also can be applied to a **DataFrame**
#
# So we can perform value counts on *combinations of column values*

# %%
car_df
# Out:
#      Brand     Model   Color  Value1  Value2  Value Sum          Car Name  \
# 0   Toyota   Corolla    Blue       5    2.45       7.45    Toyota Corolla
# 1   Toyota     Prius    Grey       3    3.45       6.45      Toyota Prius
# 2   Toyota   4Runner    Blue       6    6.53      12.53    Toyota 4Runner
# 3     Ford         K  Yellow      10   23.23      33.23            Ford K
# 4     Ford         T   Black      12   53.50      65.50            Ford T
# 5  Porsche   Cayenne   White     150  230.32     380.32   Porsche Cayenne
# 6  Porsche  Panamera     Red     200  333.30     533.30  Porsche Panamera
# 7  Porsche  Panamera   White     190   89.30     279.30  Porsche Panamera
#
#      Car Type
# 0     Toyota5
# 1     Toyota3
# 2     Toyota6
# 3      Ford10
# 4      Ford12
# 5  Porsche150
# 6  Porsche200
# 7  Porsche190

# %%
car_df[['Brand', 'Color']].value_counts()
# Out:
# Brand    Color
# Porsche  White     2
# Toyota   Blue      2
# Ford     Black     1
#          Yellow    1
# Porsche  Red       1
# Toyota   Grey      1
# dtype: int64

# %%
car_df['Brand'].value_counts()

# %% [markdown]
# Here's a trick. Suppose we want to grab the brand listed the most times

# %%
brand_counts = car_df['Brand'].value_counts()
brand_counts
# Out:
# Toyota     3
# Porsche    3
# Ford       2
# Name: Brand, dtype: int64

# %%
# One method.
# Use .idxmax()
# Returns the row index (remember this is a series) of the first largest value
brand_counts.idxmax()
# Out:
# 'Toyota'

# %%
# What about using a mask?
max_mask = brand_counts == brand_counts.max()
max_mask
# Out:
# Toyota      True
# Porsche     True
# Ford       False
# Name: Brand, dtype: bool

# %%
brand_counts[max_mask]
# Out:
# Toyota     3
# Porsche    3
# Name: Brand, dtype: int64

# %%
brand_counts[max_mask].index #.values #.tolist()

# %% [markdown]
# # Unique and Nunique

# %% [markdown]
# If we want to return a list of unique itmes in a particular column we can use `unique()`
#
# And if we want the number of unique items in a particular column we can use `nunique()`

# %%
car_df
# Out:
#      Brand     Model   Color  Value1  Value2  Value Sum          Car Name  \
# 0   Toyota   Corolla    Blue       5    2.45       7.45    Toyota Corolla
# 1   Toyota     Prius    Grey       3    3.45       6.45      Toyota Prius
# 2   Toyota   4Runner    Blue       6    6.53      12.53    Toyota 4Runner
# 3     Ford         K  Yellow      10   23.23      33.23            Ford K
# 4     Ford         T   Black      12   53.50      65.50            Ford T
# 5  Porsche   Cayenne   White     150  230.32     380.32   Porsche Cayenne
# 6  Porsche  Panamera     Red     200  333.30     533.30  Porsche Panamera
# 7  Porsche  Panamera   White     190   89.30     279.30  Porsche Panamera
#
#      Car Type
# 0     Toyota5
# 1     Toyota3
# 2     Toyota6
# 3      Ford10
# 4      Ford12
# 5  Porsche150
# 6  Porsche200
# 7  Porsche190

# %%
car_df['Color'].unique()
# Out:
# array(['Blue', 'Grey', 'Yellow', 'Black', 'White', 'Red'], dtype=object)

# %%
car_df['Color'].nunique()
# Out:
# 6

# %% [markdown]
# The docs on `unique()` tell you how to use the function, and also tell you some similar functions
#
# https://pandas.pydata.org/docs/reference/api/pandas.Series.unique.html#pandas.Series.unique

# %% [markdown]
# `drop_duplicates()` is a useful function to know
#
# Can work on a DataFrame

# %%
car_df.drop_duplicates() #< - No impact as there are no duplicates in our dataframe
# Out:
#      Brand     Model   Color  Value1  Value2  Value Sum          Car Name  \
# 0   Toyota   Corolla    Blue       5    2.45       7.45    Toyota Corolla
# 1   Toyota     Prius    Grey       3    3.45       6.45      Toyota Prius
# 2   Toyota   4Runner    Blue       6    6.53      12.53    Toyota 4Runner
# 3     Ford         K  Yellow      10   23.23      33.23            Ford K
# 4     Ford         T   Black      12   53.50      65.50            Ford T
# 5  Porsche   Cayenne   White     150  230.32     380.32   Porsche Cayenne
# 6  Porsche  Panamera     Red     200  333.30     533.30  Porsche Panamera
# 7  Porsche  Panamera   White     190   89.30     279.30  Porsche Panamera
#
#      Car Type
# 0     Toyota5
# 1     Toyota3
# 2     Toyota6
# 3      Ford10
# 4      Ford12
# 5  Porsche150
# 6  Porsche200
# 7  Porsche190

# %%
car_df['Brand'].drop_duplicates()

# %% [markdown]
# # GroupBy

# %%
car_df
# Out:
#      Brand     Model   Color  Value1  Value2  Value Sum          Car Name  \
# 0   Toyota   Corolla    Blue       5    2.45       7.45    Toyota Corolla
# 1   Toyota     Prius    Grey       3    3.45       6.45      Toyota Prius
# 2   Toyota   4Runner    Blue       6    6.53      12.53    Toyota 4Runner
# 3     Ford         K  Yellow      10   23.23      33.23            Ford K
# 4     Ford         T   Black      12   53.50      65.50            Ford T
# 5  Porsche   Cayenne   White     150  230.32     380.32   Porsche Cayenne
# 6  Porsche  Panamera     Red     200  333.30     533.30  Porsche Panamera
# 7  Porsche  Panamera   White     190   89.30     279.30  Porsche Panamera
#
#      Car Type
# 0     Toyota5
# 1     Toyota3
# 2     Toyota6
# 3      Ford10
# 4      Ford12
# 5  Porsche150
# 6  Porsche200
# 7  Porsche190

# %%
car_df.groupby(['Brand'])

# %% [markdown]
# Just calling `groupby` returns a groupby object.
#
# See docs: https://pandas.pydata.org/docs/reference/groupby.html
#
# You've grouped the data together my `Brand`, but you haven't yet done anything with the grouped data.
#
# You can now apply a function to the grouped data, such as `.sum()`, `.max()`, `.count()`, etc.

# %%
car_df
# Out:
#      Brand     Model   Color  Value1  Value2  Value Sum          Car Name  \
# 0   Toyota   Corolla    Blue       5    2.45       7.45    Toyota Corolla
# 1   Toyota     Prius    Grey       3    3.45       6.45      Toyota Prius
# 2   Toyota   4Runner    Blue       6    6.53      12.53    Toyota 4Runner
# 3     Ford         K  Yellow      10   23.23      33.23            Ford K
# 4     Ford         T   Black      12   53.50      65.50            Ford T
# 5  Porsche   Cayenne   White     150  230.32     380.32   Porsche Cayenne
# 6  Porsche  Panamera     Red     200  333.30     533.30  Porsche Panamera
# 7  Porsche  Panamera   White     190   89.30     279.30  Porsche Panamera
#
#      Car Type
# 0     Toyota5
# 1     Toyota3
# 2     Toyota6
# 3      Ford10
# 4      Ford12
# 5  Porsche150
# 6  Porsche200
# 7  Porsche190

# %%
car_df.groupby(['Brand']).sum()
# Out:
# C:\Users\Alex\AppData\Local\Temp\ipykernel_18704\3625488647.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   car_df.groupby(['Brand']).sum()
#          Value1  Value2  Value Sum
# Brand
# Ford         22   76.73      98.73
# Porsche     540  652.92    1192.92
# Toyota       14   12.43      26.43

# %%
car_df.groupby(['Brand'])[['Value1']].sum()
# Out:
#          Value1
# Brand
# Ford         22
# Porsche     540
# Toyota       14

# %%
car_df.groupby(['Brand', 'Color'])[['Value1']].sum()
# Out:
#                 Value1
# Brand   Color
# Ford    Black       12
#         Yellow      10
# Porsche Red        200
#         White      340
# Toyota  Blue        11
#         Grey         3

# %% [markdown]
# # Handling NaNs

# %% [markdown]
# Often you'll want to check if there are any NaN (Not a Number) values in your dataset.
#
# These are like missing data, and can often "throw a wrench" in your calculations
#
# Let's return to our Pokemon Data to check if

# %%
na_data = [[1, 2, np.nan, np.nan],
           [3, np.nan, np.nan, np.nan],
           [2, np.nan, np.nan, np.nan],
           [3, 3, 4, np.nan],
           [1, 3, 2, np.nan]]


nan_df = pd.DataFrame(na_data)  

nan_df
# Out:
#    0    1    2   3
# 0  1  2.0  NaN NaN
# 1  3  NaN  NaN NaN
# 2  2  NaN  NaN NaN
# 3  3  3.0  4.0 NaN
# 4  1  3.0  2.0 NaN

# %% [markdown]
# There are many ways to drop NaN values depending your requirements
#
# The `dropna` function is used to remove nan values
#
# See docs: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html

# %% [markdown]
# By default, it drops **rows** from the dataframe containing any (at least one) NaN

# %%
nan_df.dropna()
# Out:
# Empty DataFrame
# Columns: [0, 1, 2, 3]
# Index: []

# %% [markdown]
# We can change this to drop **columns** with any (at least one) NaN by changing the **axis** keyword to axis=1

# %%
nan_df.dropna(axis=1)
# Out:
#    0
# 0  1
# 1  3
# 2  2
# 3  3
# 4  1

# %% [markdown]
# We can also make a change so that it drops **rows** containing *all* NaNs

# %%
nan_df.dropna(how='all') #<- Here, there are no rows that contain ALL NaNs, so no change
# Out:
#    0    1    2   3
# 0  1  2.0  NaN NaN
# 1  3  NaN  NaN NaN
# 2  2  NaN  NaN NaN
# 3  3  3.0  4.0 NaN
# 4  1  3.0  2.0 NaN

# %% [markdown]
# And we can make a change to drop **columns** containing *all* NaNs

# %%
nan_df
# Out:
#    0    1    2   3
# 0  1  2.0  NaN NaN
# 1  3  NaN  NaN NaN
# 2  2  NaN  NaN NaN
# 3  3  3.0  4.0 NaN
# 4  1  3.0  2.0 NaN

# %%
nan_df.dropna(axis=0, how='all')
# Out:
#    0    1    2   3
# 0  1  2.0  NaN NaN
# 1  3  NaN  NaN NaN
# 2  2  NaN  NaN NaN
# 3  3  3.0  4.0 NaN
# 4  1  3.0  2.0 NaN

# %% [markdown]
# Now let's look at our Pokemon dataframe
#
# Here are some methods to check which rows, or columns have NaNs, and how many

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.isnull()
# Out:
#          #   Name  Type 1  Type 2     HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0    False  False   False   False  False   False    False    False    False
# 1    False  False   False   False  False   False    False    False    False
# 2    False  False   False   False  False   False    False    False    False
# 3    False  False   False   False  False   False    False    False    False
# 4    False  False   False    True  False   False    False    False    False
# ..     ...    ...     ...     ...    ...     ...      ...      ...      ...
# 795  False  False   False   False  False   False    False    False    False
# 796  False  False   False   False  False   False    False    False    False
# 797  False  False   False   False  False   False    False    False    False
# 798  False  False   False   False  False   False    False    False    False
# 799  False  False   False   False  False   False    False    False    False
#
#      Speed  Generation  Legendary
# ...

# %%
df.isnull().any(axis=0)
# Out:
# #             False
# Name          False
# Type 1        False
# Type 2         True
# HP            False
# Attack        False
# Defense       False
# Sp. Atk       False
# Sp. Def       False
# Speed         False
# Generation    False
# Legendary     False
# dtype: bool

# %%
df.isnull().all(axis=0)
# Out:
# #             False
# Name          False
# Type 1        False
# Type 2        False
# HP            False
# Attack        False
# Defense       False
# Sp. Atk       False
# Sp. Def       False
# Speed         False
# Generation    False
# Legendary     False
# dtype: bool

# %%
df.isnull()
# Out:
#          #   Name  Type 1  Type 2     HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0    False  False   False   False  False   False    False    False    False
# 1    False  False   False   False  False   False    False    False    False
# 2    False  False   False   False  False   False    False    False    False
# 3    False  False   False   False  False   False    False    False    False
# 4    False  False   False    True  False   False    False    False    False
# ..     ...    ...     ...     ...    ...     ...      ...      ...      ...
# 795  False  False   False   False  False   False    False    False    False
# 796  False  False   False   False  False   False    False    False    False
# 797  False  False   False   False  False   False    False    False    False
# 798  False  False   False   False  False   False    False    False    False
# 799  False  False   False   False  False   False    False    False    False
#
#      Speed  Generation  Legendary
# ...

# %%
df.isnull().sum(axis=0)
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %% [markdown]
# # Some Quick Plotting

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df['HP'].hist()
# Out:
# <Axes: >

# %%
plt.hist(df['HP']) #, bins=10) #,bins=np.arange(0, 300, 10))
plt.xlabel('HP')
plt.ylabel('Count')
plt.title('Hit Points Distribution')

df['HP'].mean()
# Out:
# 69.25875

# %%
f, ax = plt.subplots()

ax.hist(df['HP'])
ax.set_xlabel('HP')
ax.set_ylabel('Count')
ax.set_title('Hit Points Distribution')
# Out:
# Text(0.5, 1.0, 'Hit Points Distribution')

# %%
f, axs = plt.subplots(2)#, figsize=(8,8), sharex=True)

axs[0].hist(df['HP'])
axs[0].set_xlabel('HP')
axs[0].set_ylabel('Count')
axs[0].set_title('Hit Points Distribution')

axs[1].hist(df['Attack'])
axs[1].set_xlabel('Attack')
axs[1].set_ylabel('Count')
axs[1].set_title('Attack Distribution')

#plt.tight_layout()
# Out:
# Text(0.5, 1.0, 'Attack Distribution')

# %%
# axs is an array
axs
# Out:
# array([<Axes: title={'center': 'Hit Points Distribution'}, xlabel='HP', ylabel='Count'>,
#        <Axes: title={'center': 'Attack Distribution'}, xlabel='Attack', ylabel='Count'>],
#       dtype=object)

# %%
X = df['Attack']
Y = df['Defense']

plt.scatter(X,Y)

# %%
X = df['Attack']
Y = df['Defense']

f, ax = plt.subplots()

ax.scatter(X,Y)

#ax.set_xscale('log')
#ax.set_yscale('log')

# %% [markdown]
# End

# %%
#brand_counts[brand_counts==brand_counts.max()].index.tolist()

# %%
#brand_df = pd.DataFrame(brand_counts)
#brand_df[brand_df == brand_df.max()]

# %%
# Value Counts
#car_df['Brand'].value_counts()
#car_df['Color'].value_counts()
#car_df[['Brand','Color']].value_counts()

# %%
#pd.concat([car_df, pd.DataFrame(new_row, index=[0])], ignore_index=True)

# %%
#Other Functions

# %%
#car_df.max()

# %%
#car_df.max(axis=1)

# %%
#car_df.apply(lambda x: x+x)

# %%
#df['Type 1'].value_counts()

# %%
# Value Counts
#car_df['Brand'].value_counts()
#car_df['Color'].value_counts()
#car_df[['Brand','Color']].value_counts()

# %%
#df.isnull().any(axis=0)

# %%
#df[df.isnull().any(axis=1)]

# %%
#car_df.dtypes

# %%
#np.array(car_df)
